# %% [markdown]
# <a href="https://colab.research.google.com/github/amruthkumarp/Regression_model/blob/main/Inbuilt_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
# 1. Load the dataset
california = fetch_california_housing()
X = pd.DataFrame(california.data, columns=california.feature_names)
y = california.target

# %%
# Show feature names
print("Features:", california.feature_names)
# Out:
# Features: ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
# 2. Let's pick one feature for simple linear regression: 'MedInc' (median income)
X_feature = X[['MedInc']]  # keep it 2D

# %%
# 3. Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_feature, y, test_size=0.2, random_state=42)

# %%
# 4. Fit linear regression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 5. Predict
y_pred = model.predict(X_test)
print("intercept:",model.intercept_)
print("slope:",model.coef_)
# Out:
# intercept: 0.4445972916907879
# slope: [0.41933849]

# %%
# 6. Evaluate
print("R² score:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# R² score: 0.45885918903846656
# MSE: 0.7091157771765549

# %%
# 7. Plot results
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Predicted Line')
plt.xlabel("Median Income")
plt.ylabel("House Value")
plt.title("California Housing: Linear Regression on MedInc")
plt.legend()
plt.show()
